# %%
# %pip install -q llama_index
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q llama-index-vector-stores-chroma
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-legacy 0.9.48.post4 requires tenacity<9.0.0,>=8.2.0, but you have tenacity 9.0.0 which is incompatible.
# streamlit 1.32.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.2 which is incompatible.
# streamlit 1.32.0 requires tenacity<9,>=8.1.0, but you have tenacity 9.0.0 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %%
OPENAI_API_KEY='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'

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.multi_modal_llms.openai import OpenAIMultiModal

openai_mm_llm = OpenAIMultiModal(
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
    max_new_tokens=500,
    temperature=0.0,
)

# %%
# put your local directory here
image_documents = SimpleDirectoryReader(
            input_files=["./data/Example_Paper.pdf"]
).load_data()

# %%
query = "Analyse the image"
# query = "Describe the image in-depth"

response_1 = openai_mm_llm.complete(
    prompt=query,
    image_documents=image_documents,
)

print(response_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 query = "Analyse the image"
#       2 # query = "Describe the image in-depth"
# ----> 4 response_1 = openai_mm_llm.complete(
#       5     prompt=query,
#       6     image_documents=image_documents,
#       7 )
#       9 print(response_1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# ...

# %%
# Remove the OpenAIMultiModal import and replace with regular OpenAI
from llama_index.llms.openai import OpenAI
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Document
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext

# Initialize regular OpenAI LLM instead of MultiModal
llm = OpenAI(
    model="gpt-4",
    api_key=OPENAI_API_KEY,
    max_new_tokens=500,
    temperature=0.0,
)

# Load PDF documents directly without image processing
documents = SimpleDirectoryReader(
    input_dir="/Users/andreeabodea/ANDREEA/MT/Code/masters-thesis/data/",
    file_extractor={
        ".pdf": "default"  # This tells LlamaIndex to use default PDF extraction
    }
).load_data()

# Create the index directly from documents
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex.from_documents(
    documents=documents,
    llm=llm,
    storage_context=storage_context,
    show_progress=True
)
# Out:
# Failed to load file /Users/andreeabodea/ANDREEA/MT/Code/masters-thesis/data/Example_Paper.pdf with error: 'str' object has no attribute 'load_data'. Skipping...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 24
#      16 documents = SimpleDirectoryReader(
#      17     input_dir="/Users/andreeabodea/ANDREEA/MT/Code/masters-thesis/data/",
#      18     file_extractor={
#      19         ".pdf": "default"  # This tells LlamaIndex to use default PDF extraction
#      20     }
#      21 ).load_data()
#      23 # Create the index directly from documents
# ---> 24 storage_context = StorageContext.from_defaults(vector_store=vector_store)
#      25 index = VectorStoreIndex.from_documents(
#      26     documents=documents,
#      27     llm=llm,
#      28     storage_context=storage_context,
#      29     show_progress=True
#      30 )
#
# ...

# %%
query = "Describe the image"
# query = "Describe the image in-depth"

response_1 = openai_mm_llm.complete(
    prompt=query,
    image_documents=image_documents,
)

print(response_1)
# Out:
# The image is a slide titled "Problem" and discusses the challenges faced by service providers in integrating different vehicle types and brands into their business models. It highlights two main groups:
#
# 1. **Consumer services**: Aim to reach users who own different vehicles.
# 2. **Fleet operators**: Want to manage a multi-brand, multi-vehicle fleet.
#
# The slide notes that service providers lack an easy way to achieve this integration. It lists specific concerns:
#
# - They don't want to spend time on multiple integrations.
# - Dealing with car tech and vehicle makers is challenging.
# - Services want to focus on their business and customer experience (CX).
#
# The slide includes the logo "2hire" at the bottom right corner.

# %%
query = "This image is part of a slidedeck, describe the relevant content for analysis of the presentation."
# query = "Describe the image in-depth"

response_2 = openai_mm_llm.complete(
    prompt=query,
    image_documents=image_documents,
)

print(response_2)
# Out:
# The slide addresses a problem faced by service providers in integrating various vehicle types and brands into their business models. It highlights two main groups affected:
#
# 1. **Consumer Services**: These services aim to reach users who own different vehicles.
# 2. **Fleet Operators**: These operators want to manage a multi-brand, multi-vehicle fleet.
#
# The slide outlines challenges these groups face:
#
# - They want to avoid spending time on multiple integrations.
# - Dealing with car technology and vehicle markers is cumbersome.
# - They prefer to focus on their core business and customer experience (CX).

# %%
# db.delete_collection("gpt-4o-embeddings")
# db.delete_collection("5pitches-embeddings")

# %%
import os
import chromadb
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Document
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext
from llama_index.multi_modal_llms.openai import OpenAIMultiModal
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI

os.environ["OPENAI_API_KEY"] = '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'

# Directory to persist ChromaDB
persist_directory = "/content/drive/My Drive/Colab Notebooks/data/chromadb"

# Initialize ChromaDB Persistent Client
db = chromadb.PersistentClient(path=persist_directory)

# Get or create a ChromaDB collection
collection_name = "100pitches-embeddings"
chroma_collection = db.get_or_create_collection(collection_name)

# Create ChromaVectorStore and StorageContext
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# Initialize OpenAIMultiModal
openai_mm_llm = OpenAIMultiModal(
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
    max_new_tokens=500,
    temperature=0.0,
)

# Directory containing images
image_directory = "/content/drive/My Drive/Colab Notebooks/data/slides"

# Check if image directory exists
if not os.path.isdir(image_directory):
    print(f"Error: Directory '{image_directory}' does not exist.")
    exit(1)

# Load all image files from the directory
image_files = [
    os.path.join(image_directory, f)
    for f in os.listdir(image_directory)
    if f.endswith(".png")
]

# Process each image and build documents
documents = []
for image_file in sorted(image_files):
    try:
        # Load image document
        image_documents = SimpleDirectoryReader(input_files=[image_file]).load_data()

        # Define the query
        query = "This image is part of a slide deck, describe the relevant content for analysis of the presentation."

        # Get the response
        response = openai_mm_llm.complete(
            prompt=query,
            image_documents=image_documents,
        )
        print(f"Processing image: {image_file}")
        print(f"Response: {response.text}")
        print("---------------------------------")

        startup = image_file.split('slides/')[1].split('_')[0]
        # Convert the response to a Document object
        document = Document(
            text=response.text,
            doc_id=os.path.basename(image_file),  # Use filename as ID
            extra_info={"startup": startup},
        )
        documents.append(document)

    except Exception as e:
        print(f"Error processing {image_file}: {e}")


llm = OpenAI(model="gpt-4")
# Build a VectorStoreIndex using the processed documents
if documents:
    chroma_index = VectorStoreIndex.from_documents(
        documents=documents,
        llm=llm,
        storage_context=storage_context,
        show_progress=True,
    )
    print("Index built successfully and saved to ChromaDB.")
else:
    print("No documents were processed to build the index.")
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#
# 1. **Importance of Critical Materials:**
#    - Essential for economic prosperity.
#    - Integral to daily-life products.
#    - Enable technological progress.
#    - Subject to supply risks and lack easy substitutes.
#
# 2. **Materials Officially Claimed as Critical:**
#    - **Cobalt:**
#      - 60% sourced from DR Congo.
#      - Concerns about human rights and child labor.
#    - **Nickel:**
#      - Supply risk due to high concentration in a few countries.
#    - **Graphite:**
#      - 80% sourced from China.
#      - Demand is expected to grow at a 30% CAGR.
#
# 3. **Right Panel:**
#    - Emphasizes the future of clean technologies and infrastructure.
#    - Relies on the access to and management of "critical materials."
#
# This slide highlights the strategic importance and challenges associated with sourcing critical materials for lithium-ion batteries.
# ---------------------------------
# ...

# %%
import json

# Custom serialization for Document objects
class DocumentEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, Document):
            return {
                "text": obj.text,
                "doc_id": obj.doc_id,
                "extra_info": obj.extra_info,
            }
        return super().default(obj)

# Save the documents to a JSON file
output_file = "/content/drive/My Drive/Colab Notebooks/data/documents.json"
with open(output_file, "w") as file:
    json.dump(documents, file, cls=DocumentEncoder, indent=4)
print(f"Documents saved to {output_file}")
# Out:
# Documents saved to /content/drive/My Drive/Colab Notebooks/data/documents.json
# <ipython-input-24-ab1dfe7db4db>:10: DeprecationWarning: Call to deprecated function (or staticmethod) extra_info. ('extra_info' is deprecated, use 'metadata' instead.) -- Deprecated since version 0.12.2.
#   "extra_info": obj.extra_info,

# %%
# Custom deserialization for Document objects
def document_decoder(dct):
    if "text" in dct and "doc_id" in dct:
        return Document(
            text=dct["text"],
            doc_id=dct["doc_id"],
            extra_info=dct.get("extra_info", {}),
        )
    return dct

output_file = "/content/drive/My Drive/Colab Notebooks/data/documents.json"
# Load the documents from the JSON file
with open(output_file, "r") as file:
    loaded_documents = json.load(file, object_hook=document_decoder)

print(f"Loaded {len(loaded_documents)} documents from {output_file}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5bc67a36f0ff> in <cell line: 13>()
#      11 output_file = "/content/drive/My Drive/Colab Notebooks/data/documents.json"
#      12 # Load the documents from the JSON file
# ---> 13 with open(output_file, "r") as file:
#      14     loaded_documents = json.load(file, object_hook=document_decoder)
#      15
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/data/documents.json'

# %%
documents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-22162c9c5638> in <cell line: 1>()
# ----> 1 documents
#
# NameError: name 'documents' is not defined

# %%
# Convert the index to a retriever
retriever = chroma_index.as_retriever(similarity_top_k=10)

# Define your query
query_text = 'Who are the founders or who is the team for each of the startups?'

# Perform the retrieval
response = retriever.retrieve(query_text)

# Print the response
print("Query Response:")
print(response)

# Print a readable summary of the retrieved nodes
print("Query Response:\n")
for idx, node_with_score in enumerate(response, start=1):
    node = node_with_score.node  # Access the node
    print(f"Result {idx}:")
    print(f"Node ID: {node.id_}")
    print(f"Startup: {node.metadata.get('startup', 'Unknown')}")  # Extract metadata if available
    print(f"Text: {node.text}...")  # Print the first 300 characters of the text
    print(f"Score: {node_with_score.score}")
    print("-" * 40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c149a6a8f714> in <cell line: 2>()
#       1 # Convert the index to a retriever
# ----> 2 retriever = chroma_index.as_retriever(similarity_top_k=10)
#       3
#       4 # Define your query
#       5 query_text = 'Who are the founders or who is the team for each of the startups?'
#
# NameError: name 'chroma_index' is not defined

# %%
from llama_index.core.response_synthesizers import ResponseMode
from llama_index.core import get_response_synthesizer
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4")

# Initialize the response synthesizer
response_synthesizer = get_response_synthesizer(response_mode=ResponseMode.COMPACT)

# Create a query engine with the synthesizer and set top_k for the retriever
query_engine = chroma_index.as_query_engine(
    response_synthesizer=response_synthesizer,
    similarity_top_k=10,
    llm=llm
)

# from llama_index.core.postprocessor import LongContextReorder
# reorder = LongContextReorder()
# query_engine_modified = RetrieverQueryEngine.from_args(
#     retriever,
#     response_synthesizer=response_synthesizer,
#     node_postprocessors=[reorder],
# )

# Define your query
# query_text = 'Who are the founders or who is the team for all of the startups (Rencore, Silana, Fyta, Electryone, Lyntics)?'
query_text = 'You are an investment manager at a venture capital firm. You see the infromations provided for each of the startups, please choose the startups that are worth having a first call with to better understand their business. Explain based on what reasoning you are making this choice.'

# Perform the query
response = query_engine.query(query_text)

# Print the synthesized response
print("Synthesized Response:")
print(response)
# Out:
# Synthesized Response:
# I would choose to have a first call with the startups Fyta and Silana. Fyta stands out due to its strategic plan for creating high barriers to entry in the market, its financial and strategic plan for scaling product and sales, and the experienced team members and investors involved. Silana, on the other hand, showcases a clear investment overview for seed funding allocation, a strong board of advisors with expertise in relevant industries, and a team of founders with diverse backgrounds in fashion, technology, and business. These factors indicate solid business planning, industry connections, and potential for growth, making them promising candidates for further exploration.
